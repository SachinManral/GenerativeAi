# %% [markdown]
# ### LangChain version v1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.1

# %% [markdown]
# ### Generative AI Application using agents and groq Model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    "llama-3.1-8b-instant",
    model_provider="groq"
)

print(model)
# Out:
# output_version=None profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x0000029A2CDFADE0> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000029A2CDFCD40> model_name='llama-3.1-8b-instant' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %%
## First Generative AI application

response=model.invoke("Write me an essay on AI")
print(response.content)
# Out:
# **The Rise of Artificial Intelligence: Revolutionizing the World**
#
# In recent years, Artificial Intelligence (AI) has undergone a significant transformation, evolving from a concept of science fiction to a rapidly advancing field of technology. AI has become an integral part of modern life, transforming the way we live, work, and interact with each other. From virtual assistants to self-driving cars, AI has infiltrated every aspect of our lives, and its impact is only expected to grow in the coming years.
#
# The concept of AI dates back to the 1950s, when computer scientist Alan Turing proposed the idea of a machine that could think and learn like a human being. However, it wasn't until the 21st century that AI began to gain traction, thanks to the development of powerful computing systems and advances in machine learning algorithms. Today, AI is used in a wide range of applications, from image and speech recognition to natural language processing and expert systems.
#
# One of the most significant applications of AI is in the field of automation. Robots and machines are now able to perform tasks that were previously the exclusive domain of humans, such as manufacturing, transportation, and customer service. This has led to increased efficiency and productivity, as well as reduced labor costs and improved accuracy. For example, Amazon's warehouses are now staffed by robots that can pick and pack orders with ease, reducing the need for human labor and increasing the speed of delivery.
#
# Another area where AI is making significant inroads is in the field of healthcare. AI-powered systems are now being used to diagnose diseases, develop personalized treatment plans, and analyze medical data. For example, IBM's Watson system is being used to analyze cancer data and identify potential treatments, while Google's DeepMind system is being used to develop AI-powered diagnostic tools for diseases such as diabetes and heart disease.
#
# AI is also transforming the way we interact with technology. Virtual assistants such as Siri, Alexa, and Google Assistant are now ubiquitous, allowing us to control our homes, access information, and communicate with others using natural language. These assistants use machine learning algorithms to understand our voice commands and respond accordingly, making it easier for us to interact with technology.
#
# However, the rise of AI has also raised concerns about job displacement and the impact on human relationships. As machines become more capable of performing tasks that were previously the exclusive domain of humans, there is a growing fear that many jobs will be automated out of existence. This has led to calls for policymakers to develop strategies to mitigate the impact of AI on employment and to ensure that the benefits of AI are shared by all.
#
# Despite these concerns, the benefits of AI are undeniable. AI has the potential to solve some of the world's most pressing problems, from climate change to disease diagnosis. It has also the potential to improve the quality of life for billions of people, making it easier for them to access information, healthcare, and education.
#
# In conclusion, AI is transforming the world in ways that were previously unimaginable. From automation and healthcare to virtual assistants and job displacement, AI is having a profound impact on modern life. While there are concerns about the impact of AI on employment and human relationships, the benefits of AI are undeniable. As we move forward, it is essential that we develop strategies to mitigate the negative impacts of AI and to ensure that its benefits are shared by all.
#
# **References:**
#
# * Turing, A. (1950). Computing Machinery and Intelligence. Mind, 59(236), 433-460.
# * Russell, S. J., & Norvig, P. (2010). Artificial Intelligence: A Modern Approach (3rd ed.). Prentice Hall.
# * Silver, D. (2014). Machine learning. Nature, 512(7513), 127-132.
# * LeCun, Y., Bengio, Y., & Hinton, G. (2015). Deep learning. Nature, 521(7553), 436-444.
#
# **Sources:**
#
# * IBM. (2022). Watson Health.
# * Google. (2022). DeepMind.
# * Amazon. (2022). Robotics.
# * World Economic Forum. (2022). The Future of Jobs Report 2022.

# %%
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
#
# NameError: name 'os' is not defined

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Write me an essay about Artificial Intelligence")
print(response.content)
# Out:
# ## The Dawn of the Algorithmic Mind: Navigating the Landscape of Artificial Intelligence
#
# Artificial Intelligence (AI) is no longer a whispered promise of science fiction; it is a palpable force reshaping our present and charting the course of our future. From the mundane convenience of voice assistants to the profound implications of autonomous systems, AI is weaving itself into the fabric of human existence, prompting both awe and apprehension. At its core, AI represents the endeavor to imbue machines with capabilities that have historically been the exclusive domain of human intellect – learning, problem-solving, perception, and decision-making. As we stand on the precipice of this algorithmic revolution, understanding its multifaceted nature, its transformative potential, and the ethical considerations it raises becomes paramount.
#
# The journey of AI has been a long and winding one, marked by periods of fervent optimism and subsequent "AI winters." However, recent advancements in computational power, coupled with the explosion of data and sophisticated algorithms like deep learning, have propelled AI into a new era of unprecedented progress. This progress is evident in various forms. Machine learning, a cornerstone of modern AI, allows systems to learn from data without explicit programming, enabling them to identify patterns, make predictions, and adapt over time. This has led to breakthroughs in areas like image and speech recognition, natural language processing, and recommendation systems, making our digital interactions increasingly intuitive and personalized.
#
# Beyond these consumer-facing applications, AI's impact is far more profound, promising to revolutionize industries and address some of humanity's most pressing challenges. In healthcare, AI is aiding in disease diagnosis, drug discovery, and personalized treatment plans, potentially leading to more effective and accessible medical care. In transportation, autonomous vehicles hold the promise of increased safety and efficiency, while in agriculture, AI-powered systems can optimize crop yields and resource management, contributing to global food security. Furthermore, AI is proving invaluable in scientific research, accelerating discoveries in fields ranging from climate modeling to astrophysics. The ability of AI to process and analyze vast datasets at speeds far exceeding human capacity opens up new avenues for understanding complex phenomena and solving intricate problems.
#
# However, this transformative power is not without its shadows. The rapid ascent of AI also brings forth a complex web of ethical and societal challenges. Concerns surrounding job displacement due to automation are legitimate, necessitating proactive strategies for reskilling and upskilling the workforce. The potential for bias embedded within AI algorithms, often reflecting societal prejudices present in the training data, raises serious questions about fairness and equity. The development of autonomous weapons systems, for instance, ignites a debate about accountability and the very nature of warfare. Moreover, the increasing sophistication of AI raises profound questions about privacy, surveillance, and the potential for misuse by malicious actors.
#
# As AI continues its relentless march, navigating this new landscape requires careful consideration and thoughtful dialogue. We must foster an environment of responsible innovation, where the development and deployment of AI are guided by ethical principles and a commitment to human well-being. This involves establishing robust regulatory frameworks, promoting transparency in AI systems, and investing in research that addresses the ethical implications of AI. Education will play a crucial role in equipping individuals with the knowledge and skills to understand, interact with, and critically evaluate AI technologies.
#
# In conclusion, Artificial Intelligence represents a pivotal moment in human history, a testament to our ingenuity and our relentless pursuit of progress. Its potential to enhance human capabilities, solve complex problems, and drive societal advancement is undeniable. Yet, this potential is inextricably linked to the responsibility we bear in shaping its trajectory. By embracing a proactive, ethical, and collaborative approach, we can harness the power of the algorithmic mind to create a future that is not only intelligent but also equitable, sustainable, and ultimately, more human. The dawn of AI is not an endpoint, but a beginning, and the choices we make today will determine the shape of the world tomorrow.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response=model.invoke("Write me an essay about Artificial Intelligence")
print(response.content)

# %%
response=model.invoke("Make joke on the machine learning")
print(response.content)

# %% [markdown]
# ## Streaming and Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experiences, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time.

# %%
model.invoke("Write me a 500 words paragraph on AI")
# Out:
# AIMessage(content='Artificial Intelligence (AI) is a transformative force, rapidly reshaping our world by imbuing machines with capabilities once exclusively attributed to human intellect. At its core, AI encompasses the development of computer systems that can perform tasks typically requiring human intelligence, such as learning, problem-solving, perception, and decision-making. This is achieved through a variety of techniques, most notably machine learning, where algorithms learn from vast datasets without explicit programming, identifying patterns and making predictions. Deep learning, a subset of machine learning utilizing artificial neural networks with multiple layers, has been particularly instrumental in recent AI advancements, powering breakthroughs in image recognition, natural language processing, and even creative endeavors.\n\nThe applications of AI are becoming ubiquitous, permeating nearly every sector of society. In healthcare, AI assists in diagnosing diseases with greater accuracy, personalizing treatment plans, and accelerating drug discovery. The automotive industry is witnessing the rise of autonomous vehicles, promising enhanced safety and efficiency. In finance, AI algorithms are employed for fraud detection, algorithmic trading, and personalized financial advice. Customer service is being revolutionized by chatbots and virtual assistants, offering instant support and improving user experience. Furthermore, AI is playing a crucial role in scientific research, helping to analyze complex data, simulate experiments, and uncover new insights in fields ranging from climate science to astrophysics.\n\nHowever, the rapid ascent of AI also brings forth significant ethical and societal considerations. Concerns surrounding job displacement due to automation are prevalent, necessitating proactive strategies for workforce reskilling and adaptation. Bias embedded within training data can lead to discriminatory AI systems, highlighting the critical importance of fair and equitable data practices. The potential for misuse of AI in surveillance and autonomous weapons systems raises profound questions about privacy, security, and human control. Ensuring transparency and accountability in AI development and deployment is paramount to fostering public trust and mitigating potential risks. As AI continues its evolutionary journey, navigating these challenges responsibly will be crucial to harnessing its immense potential for good and building a future where AI serves humanity ethically and beneficially. The ongoing dialogue and collaboration between researchers, policymakers, and the public are essential to shaping this future, ensuring that AI remains a tool for progress and human flourishing.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3968-d0c7-7e21-9510-0ade68c36bdf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 12, 'output_tokens': 431, 'total_tokens': 443, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ## Out will be in a flow

# %%
for chunk in model.stream("Write me a 500 words paragraph on AI"):
    print(chunk.text, end="", flush=True)

# %%
model.invoke("why do parrots have colorful feathers")
# Out:
# AIMessage(content="Parrots have colorful feathers for a variety of fascinating reasons, primarily revolving around **survival and reproduction**:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** The vibrant and often unique color patterns help parrots identify members of their own species. This is crucial for mating, flock cohesion, and recognizing potential threats or allies. Imagine trying to find your mate in a dense rainforest if everyone looked the same!\n* **Individual Recognition:** Within a species, subtle variations in color can help individuals recognize each other. This can be important for social hierarchies, family bonds, and recognizing familiar individuals.\n* **Mood and Intent:** Some color changes can be subtle indicators of a parrot's emotional state, such as excitement, aggression, or fear. While not as dramatic as some other animals, these visual cues can play a role in their interactions.\n* **Mating Displays:** Bright and elaborate plumage is often a key component of courtship rituals. Males may display their colors to attract females, signaling their health, vigor, and genetic quality. Females may also have preferences for certain colors or patterns.\n\n**2. Camouflage (Paradoxically):**\n\n* **Breaking Up Outline:** While bright colors might seem counterintuitive for hiding, in certain environments, they can actually help break up a parrot's outline against a complex background of leaves, flowers, and fruits. This can make them harder for predators to spot.\n* **Mimicking Environment:** Some parrots have colors that blend remarkably well with their specific habitats. For example, a parrot living amongst vibrant flowers might have similar hues.\n\n**3. Warning Signals (Aposematism):**\n\n* **Toxicity or Danger:** In some cases, bright colors can serve as a warning to potential predators that the parrot is either toxic, venomous, or otherwise dangerous to eat. While this is less common in parrots than in insects or amphibians, it's a possibility in certain species.\n\n**4. Thermoregulation (Less Significant):**\n\n* **Heat Absorption/Reflection:** Darker feathers absorb more sunlight and heat, while lighter feathers reflect it. While not the primary driver of their vibrant colors, there might be some subtle thermoregulatory benefits. However, this is generally considered a secondary factor compared to communication.\n\n**5. Pigments and Structural Color:**\n\nThe vibrant colors are created by two main mechanisms:\n\n* **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.\n    * **Melanins:** Produce black, brown, and some muted yellows and reds.\n    * **Carotenoids:** Obtained from their diet (fruits, vegetables), these produce bright reds, oranges, and yellows. This is why a parrot's diet is so crucial for its coloration.\n    * **Psittacofulvins:** Unique to parrots, these pigments produce vibrant reds, oranges, and yellows.\n* **Structural Color:** This is created by the microscopic structure of the feather barbules. When light hits these structures, it scatters and interferes in a way that produces iridescent blues, greens, and violets. This is similar to how a soap bubble or a CD appears colorful.\n\n**In summary, the colorful feathers of parrots are a testament to the power of natural selection. They are a sophisticated tool that helps them navigate their social world, find mates, and survive in their environment. The exact combination of colors and their significance can vary greatly between different parrot species, reflecting their unique evolutionary histories and ecological niches.**", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e3968-ee3f-7d40-9a98-9d66086e868f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 715, 'total_tokens': 722, 'input_ ...

# %%
from sys import flags
for chunk in model.stream("why do parrots have the colorful feathers"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots are famous for their vibrant and diverse feather colors, and there are several fascinating evolutionary reasons behind this dazzling display. It's not just about looking pretty; these colors play crucial roles in their survival and reproduction. Here are the main reasons why parrots have colorful feathers:
#
# **1. Communication and Social Signaling:**
#
# *   **Species Recognition:** In a flock of hundreds or thousands of parrots, distinct color patterns help individuals recognize members of their own species. This is vital for finding mates, forming social bonds, and coordinating group activities like foraging and predator avoidance.
# *   **Individual Recognition:** Within a species, subtle variations in color and markings can help parrots identify specific individuals, such as their mates, offspring, or flock members.
# *   **Mood and Health Indicators:** The intensity and brightness of certain colors can sometimes signal a parrot's emotional state, health, and readiness to mate. For example, brighter plumage might indicate a healthy, dominant individual.
# *   **Social Hierarchy:** In some species, specific color patterns might be associated with dominance or subordinate roles within a flock.
#
# **2. Mating and Sexual Selection:**
#
# *   **Attracting Mates:** For many species, especially in areas with dense foliage where visual cues can be important, bright and attractive plumage is a key factor in attracting a mate. Males often have more vibrant colors to impress females, who then choose mates based on these displays. This is a classic example of sexual selection.
# *   **Assessing Mate Quality:** The brightness and completeness of a parrot's plumage can also be an indicator of its health, diet, and overall genetic fitness. A healthy parrot can afford to invest more in producing vibrant pigments.
#
# **3. Camouflage and Predator Avoidance:**
#
# *   **Blending In:** While often thought of as brightly colored, many parrot species utilize their colors to blend into their specific environments. For example, parrots living in lush green rainforests often have significant green coloration, helping them disappear among the leaves.
# *   **Disruptive Coloration:** Bold patterns and contrasting colors can break up the outline of a parrot, making it harder for predators to spot them. This is similar to how zebras' stripes confuse predators.
# *   **Warning Signals (Less Common):** In some cases, very bright and conspicuous colors might serve as a warning to predators that the bird is toxic or unpalatable, although this is less common in parrots compared to other bird groups.
#
# **4. Thermoregulation:**
#
# *   **Heat Absorption and Dissipation:** Darker feathers absorb more sunlight, which can be beneficial in cooler environments or during colder parts of the day. Lighter or iridescent feathers might reflect more sunlight, helping to prevent overheating in hotter climates. The specific arrangement and types of feathers can also play a role in insulation.
#
# **5. Pigments and Structural Colors:**
#
# The colors themselves are produced in two main ways:
#
# *   **Pigments:** These are chemical compounds that absorb certain wavelengths of light and reflect others.
#     *   **Melanins:** Produce blacks, browns, grays, and some dull yellows.
#     *   **Porphyrins:** Produce reds, oranges, and some greens. These are less common in birds and can degrade in sunlight.
# *   **Structural Colors:** These are created by the microscopic structure of the feathers themselves. The way light interacts with these structures causes certain wavelengths to be reflected or scattered, creating iridescent blues, greens, and violets. This is why some parrot feathers can change color depending on the viewing angle.
#
# **In summary, the dazzling array of colors in parrots is a result of a complex interplay of evolutionary pressures. These colors are not merely for show; they are essential tools for communication, reproduction, survival, and even physiological regulation.**

# %% [markdown]
# ### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel.

# %%
reponses = model.batch([
    "why do parrots have colorful feathers",
    "how do an ai works",
    "what is the newtons third law"
])
for reponse in reponses:
    print(reponses)
# Out:
# [AIMessage(content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here's a breakdown of the main factors:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** The vibrant and often unique color patterns of parrots are crucial for identifying members of their own species. In dense rainforests where visibility can be limited, bright colors help parrots quickly spot and recognize their mates, flock members, and potential rivals.\n* **Mate Attraction:** In many parrot species, bright colors are a significant factor in sexual selection. Males often display their most vibrant plumage to attract females. The intensity and health of their colors can signal their genetic quality, fitness, and ability to find good food sources. Females may choose mates with more striking colors.\n* **Social Status and Dominance:** Color patterns can also indicate an individual's social status within a flock. Brighter, more intense colors might be associated with dominant individuals, while duller colors could signal a subordinate position. This can help reduce aggressive encounters by clearly communicating hierarchies.\n* **Emotional State:** While not as prominent as in some other birds, color can sometimes subtly change with a parrot's mood. For example, a parrot might flush with brighter colors when excited or agitated.\n\n**2. Camouflage (Sometimes, but not always the primary driver):**\n\n* **Against Predators:** While we often associate bright colors with being conspicuous, in some environments, parrot coloration can actually aid in camouflage. For instance, if a parrot lives in a forest with brightly colored flowers or fruits, its own colors might help it blend in with its surroundings, making it harder for predators to spot.\n* **Disruptive Coloration:** Complex patterns of different colors can break up the outline of a parrot's body, making it harder for predators to recognize it as prey.\n\n**3. Diet and Nutrition:**\n\n* **Carotenoids:** Many of the bright pigments in parrot feathers, particularly yellows, oranges, and reds, come from carotenoids. These are pigments that parrots obtain from their diet, primarily from fruits, vegetables, and seeds. The ability to acquire and process these carotenoids can be an indicator of a parrot's health and foraging skills. A parrot that can maintain vibrant colors likely has access to a good and varied diet.\n\n**4. Thermoregulation (Less significant, but still a factor):**\n\n* **Heat Absorption:** Darker feathers absorb more solar radiation, which can be beneficial in cooler environments or during colder parts of the day. Lighter feathers might reflect more sunlight, helping to keep a parrot cool in hot climates. While parrots are generally found in tropical and subtropical regions, there can still be variations in temperature.\n\n**5. Melanin-Based Colors:**\n\n* **Black and Brown:** These colors are produced by melanin pigments, which are very durable and provide structural strength to feathers. They are also important for absorbing UV radiation, which can damage DNA.\n\n**In summary, the vibrant colors of parrots are a multi-faceted evolutionary adaptation:**\n\n* **Primary drivers are communication and mate selection.**\n* **Camouflage plays a role in certain environments.**\n* **Dietary availability of pigments influences color intensity.**\n\nThe diversity of color patterns across the vast array of parrot species highlights how these factors have shaped their evolution in different ecological niches. It's a beautiful testament to the power of natural selection and the complex ways in which animals communicate and thrive.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e396d-dc7a-75f1-851c-5958eea4a898-0', tool_calls=[], invalid_tool_calls=[], usage_metadata ...
# [AIMessage(content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here's a breakdown of the main factors:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** The vibrant and often unique color patterns of parrots are crucial for identifying members of their own species. In dense rainforests where visibility can be limited, bright colors help parrots quickly spot and recognize their mates, flock members, and potential rivals.\n* **Mate Attraction:** In many parrot species, bright colors are a significant factor in sexual selection. Males often display their most vibrant plumage to attract females. The intensity and health of their colors can signal their genetic quality, fitness, and ability to find good food sources. Females may choose mates with more striking colors.\n* **Social Status and Dominance:** Color patterns can also indicate an individual's social status within a flock. Brighter, more intense colors might be associated with dominant individuals, while duller colors could signal a subordinate position. This can help reduce aggressive encounters by clearly communicating hierarchies.\n* **Emotional State:** While not as prominent as in some other birds, color can sometimes subtly change with a parrot's mood. For example, a parrot might flush with brighter colors when excited or agitated.\n\n**2. Camouflage (Sometimes, but not always the primary driver):**\n\n* **Against Predators:** While we often associate bright colors with being conspicuous, in some environments, parrot coloration can actually aid in camouflage. For instance, if a parrot lives in a forest with brightly colored flowers or fruits, its own colors might help it blend in with its surroundings, making it harder for predators to spot.\n* **Disruptive Coloration:** Complex patterns of different colors can break up the outline of a parrot's body, making it harder for predators to recognize it as prey.\n\n**3. Diet and Nutrition:**\n\n* **Carotenoids:** Many of the bright pigments in parrot feathers, particularly yellows, oranges, and reds, come from carotenoids. These are pigments that parrots obtain from their diet, primarily from fruits, vegetables, and seeds. The ability to acquire and process these carotenoids can be an indicator of a parrot's health and foraging skills. A parrot that can maintain vibrant colors likely has access to a good and varied diet.\n\n**4. Thermoregulation (Less significant, but still a factor):**\n\n* **Heat Absorption:** Darker feathers absorb more solar radiation, which can be beneficial in cooler environments or during colder parts of the day. Lighter feathers might reflect more sunlight, helping to keep a parrot cool in hot climates. While parrots are generally found in tropical and subtropical regions, there can still be variations in temperature.\n\n**5. Melanin-Based Colors:**\n\n* **Black and Brown:** These colors are produced by melanin pigments, which are very durable and provide structural strength to feathers. They are also important for absorbing UV radiation, which can damage DNA.\n\n**In summary, the vibrant colors of parrots are a multi-faceted evolutionary adaptation:**\n\n* **Primary drivers are communication and mate selection.**\n* **Camouflage plays a role in certain environments.**\n* **Dietary availability of pigments influences color intensity.**\n\nThe diversity of color patterns across the vast array of parrot species highlights how these factors have shaped their evolution in different ecological niches. It's a beautiful testament to the power of natural selection and the complex ways in which animals communicate and thrive.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e396d-dc7a-75f1-851c-5958eea4a898-0', tool_calls=[], invalid_tool_calls=[], usage_metadata ...
# [AIMessage(content="Parrots have colorful feathers for a variety of reasons, and it's a fascinating interplay of **evolution, communication, and survival**. Here's a breakdown of the main factors:\n\n**1. Communication and Social Signaling:**\n\n* **Species Recognition:** The vibrant and often unique color patterns of parrots are crucial for identifying members of their own species. In dense rainforests where visibility can be limited, bright colors help parrots quickly spot and recognize their mates, flock members, and potential rivals.\n* **Mate Attraction:** In many parrot species, bright colors are a significant factor in sexual selection. Males often display their most vibrant plumage to attract females. The intensity and health of their colors can signal their genetic quality, fitness, and ability to find good food sources. Females may choose mates with more striking colors.\n* **Social Status and Dominance:** Color patterns can also indicate an individual's social status within a flock. Brighter, more intense colors might be associated with dominant individuals, while duller colors could signal a subordinate position. This can help reduce aggressive encounters by clearly communicating hierarchies.\n* **Emotional State:** While not as prominent as in some other birds, color can sometimes subtly change with a parrot's mood. For example, a parrot might flush with brighter colors when excited or agitated.\n\n**2. Camouflage (Sometimes, but not always the primary driver):**\n\n* **Against Predators:** While we often associate bright colors with being conspicuous, in some environments, parrot coloration can actually aid in camouflage. For instance, if a parrot lives in a forest with brightly colored flowers or fruits, its own colors might help it blend in with its surroundings, making it harder for predators to spot.\n* **Disruptive Coloration:** Complex patterns of different colors can break up the outline of a parrot's body, making it harder for predators to recognize it as prey.\n\n**3. Diet and Nutrition:**\n\n* **Carotenoids:** Many of the bright pigments in parrot feathers, particularly yellows, oranges, and reds, come from carotenoids. These are pigments that parrots obtain from their diet, primarily from fruits, vegetables, and seeds. The ability to acquire and process these carotenoids can be an indicator of a parrot's health and foraging skills. A parrot that can maintain vibrant colors likely has access to a good and varied diet.\n\n**4. Thermoregulation (Less significant, but still a factor):**\n\n* **Heat Absorption:** Darker feathers absorb more solar radiation, which can be beneficial in cooler environments or during colder parts of the day. Lighter feathers might reflect more sunlight, helping to keep a parrot cool in hot climates. While parrots are generally found in tropical and subtropical regions, there can still be variations in temperature.\n\n**5. Melanin-Based Colors:**\n\n* **Black and Brown:** These colors are produced by melanin pigments, which are very durable and provide structural strength to feathers. They are also important for absorbing UV radiation, which can damage DNA.\n\n**In summary, the vibrant colors of parrots are a multi-faceted evolutionary adaptation:**\n\n* **Primary drivers are communication and mate selection.**\n* **Camouflage plays a role in certain environments.**\n* **Dietary availability of pigments influences color intensity.**\n\nThe diversity of color patterns across the vast array of parrot species highlights how these factors have shaped their evolution in different ecological niches. It's a beautiful testament to the power of natural selection and the complex ways in which animals communicate and thrive.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e396d-dc7a-75f1-851c-5958eea4a898-0', tool_calls=[], invalid_tool_calls=[], usage_metadata ...

# %%
model.batch([
    "why do parrots have colorful feathers",
    "how do an ai works",
    "what is the newtons third law"
],config={
    'max_concurrency': 5, 
}
)
# Out:
# [AIMessage(content="Parrots have colorful feathers due to a combination of factors, including:\n\n1. **Pigmentation**: Carotenoids, such as beta-carotene and lycopene, and other pigments like melanin are responsible for the bright colors in parrots' feathers. These pigments are derived from their diet, which includes fruits, leaves, and other plant-based foods rich in carotenoids.\n2. **Structural colors**: Some of the colors in parrots' feathers are created by the structure of the feathers themselves, rather than by pigments. This is called structural coloration. In this process, the microscopic structure of the feathers scatters light, producing colors that appear to change depending on the angle of view.\n3. **Melanin**: Melanin is a pigment found in the skin, hair, and feathers of many animals, including parrots. It's responsible for the brown, black, and gray colors in parrots' feathers. However, when combined with other pigments, melanin can also contribute to the production of red, orange, and yellow colors.\n4. **Evolutionary advantages**: The bright colors of parrots' feathers may serve several purposes, including:\n * **Mating and courtship**: Bright colors can attract mates and signal an individual's fitness and health.\n * **Territorial defense**: Bright colors can serve as a warning to potential predators or rivals that an individual is defended and not worth attacking.\n * **Communication**: Bright colors can be used for communication between parrots, such as signaling aggression or alarm.\n\nIn short, the colorful feathers of parrots are a result of a combination of pigments, structural colors, and evolutionary pressures that have shaped their appearance over time.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 351, 'prompt_tokens': 42, 'total_tokens': 393, 'completion_time': 0.531013087, 'completion_tokens_details': None, 'prompt_time': 0.002362842, 'prompt_tokens_details': None, 'queue_time': 0.159028517, 'total_time': 0.533375929}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e3972-3c7a-7281-83b9-60888132de5f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 351, 'total_tokens': 393}),
#  AIMessage(content="I'll provide a comprehensive overview of how AI works.\n\n**What is AI?**\n\nArtificial Intelligence (AI) is a field of computer science that enables machines to perform tasks that typically require human intelligence, such as:\n\n1. Learning\n2. Reasoning\n3. Problem-solving\n4. Perception\n5. Understanding natural language\n\n**Main Components of AI**\n\n1. **Hardware**: AI systems require powerful computers, known as GPUs (Graphics Processing Units) or TPUs (Tensor Processing Units), to perform complex calculations.\n2. **Software**: AI software includes various algorithms, frameworks, and programming languages, such as Python, TensorFlow, and PyTorch.\n3. **Data**: AI systems rely on large datasets to learn and improve their performance.\n\n**How AI Works**\n\n1. **Data Collection**: AI systems collect and preprocess data from various sources, such as text, images, or audio.\n2. **Data Storage**: The collected data is stored in a database or data storage system.\n3. **Model Training**: The AI system uses machine learning algorithms to train a model on the collected data. The model learns patterns and relationships within the data.\n4. **Model Evaluation**: The trained model is evaluated on a test dataset to assess its performance.\n5. **Model Deployment**: The trained model is deployed in a production environment, where it can make predictions or take actions on new, unseen data.\n\n**Machine Learning Algorithms**\n\nThere are several types of machine learning algorithms, including:\n\n1. **Supervised Learning**: The AI system is trained on labeled data, where the correct output is already known.\n2. **Unsupervised Learning**: The AI system is trained on unlabeled data, where the correct output is not known.\n3. **Reinforcement Learning**: The AI system learns through trial and error, receiving rewards or penalties for its actions.\n4. **Deep Learning**: A type of machine learning that uses neural networks with multiple layers to learn complex patterns in data.\n\n**Neural Networks**\n\nNeural networks are a fundamental component of AI systems. They are inspired by the structure and function of the human brain and consist of:\n\n1. **Input Layer**: Receives input data from the environment.\n2. **Hidden Layers**: Process the input data, applying various transformations and nonlinearities.\n3. **Output Layer**: Produces the final output, based on the processed input data.\n\n**Types of Neural Networks**\n\n1. **Feedforward Networks**: Data flows only in one direction, from input to output.\n2. **Recurrent Neural Networks (RNNs)**: Data flows in a loop, allowing the network to maintain internal state and learn sequential patterns.\n3. **Convolutional Neural Networks (CNNs)**: Designed for image and video processing, using convolutional and pooling layers to extract features.\n\n**AI Techniques**\n\n1. **Natural Language Processing (NLP)**: Enables AI systems to understand and generate human language.\n2. **Computer Vision**: Enables AI systems to interpret and understand visual data from images and videos.\n3. **Robotics**: Enables AI systems to interact with and manipulate the physical world.\n\n**Challenges and Limitations**\n\n1. **Bias and Fairness**: AI systems can perpetuate biases and inequalities present in the data.\n2. **Explainability**: AI systems can be difficult to interpret and understand.\n3. **Security**: AI systems can be vulnerable to attacks and data breaches.\n\nI hope this provides a comprehensive overview of how AI works!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 705, 'prompt_tokens': 40, 'total_tokens': 745, 'completion_time': 0.842715242, 'completion_tokens_details': None, 'prompt_time': 0.002340522, 'prompt_tokens_details': None, 'queue_time': 0.158871778, 'total_time': 0.845055764}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provid ...
#  AIMessage(content='Newton\'s Third Law of Motion states that:\n\n"For every action, there is an equal and opposite reaction."\n\nIn other words, when object A exerts a force on object B, object B will exert an equal and opposite force on object A. This law applies to all interactions between objects and is a fundamental concept in physics.\n\nHere are some examples to illustrate Newton\'s Third Law:\n\n1. **Walking**: When you push on the ground with your feet, the ground exerts an equal and opposite force on your feet, propelling you forward.\n2. **Throwing a ball**: When you throw a ball, the ball exerts a force on your hand, and your hand exerts an equal and opposite force on the ball, propelling it forward.\n3. **Rocket propulsion**: A rocket engine produces thrust by expelling hot gases out of the back of the rocket, which causes the rocket to move forward. The gases exert a force on the rocket, and the rocket exerts an equal and opposite force on the gases.\n4. **Pumping air into a tire**: When you pump air into a tire, the air molecules exert a force on the tire, and the tire exerts an equal and opposite force on the air molecules, causing the air to expand and the tire to inflate.\n\nNewton\'s Third Law is a fundamental principle that helps us understand the interactions between objects and how forces work in the physical world.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 287, 'prompt_tokens': 42, 'total_tokens': 329, 'completion_time': 0.35285989, 'completion_tokens_details': None, 'prompt_time': 0.002422061, 'prompt_tokens_details': None, 'queue_time': 0.159483213, 'total_time': 0.355281951}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e3972-3c95-7100-8bde-42266d7e34df-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 287, 'total_tokens': 329})]
